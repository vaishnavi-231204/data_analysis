# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # statistical info

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # datatype info

# %%
sns.countplot(train['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data=train,x='Pclass',palette='pastel')
plt.show()

# %%
sns.countplot(data=train,x='Sex',palette='muted')
plt.show()

# %%
sns.countplot(data=train,x='SibSp',palette='bright')
plt.show()

# %%
sns.countplot(data=train,x='Parch',palette='coolwarm')
plt.show()

# %%
sns.countplot(data=train,x='Embarked',palette='colorblind')
plt.show()

# %%
sns.displot(data=train, x='Age', hue='Survived', palette='coolwarm', kde=False)
plt.show()

# %%
a=train[train['Survived']==1]
a
# Out:
#      index  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  \
# 1        1            2       1.0       1    0  38.0      1      0  1.664038
# 2        2            3       1.0       3    0  26.0      0      0  1.159662
# 3        3            4       1.0       1    0  35.0      1      0  1.607603
# 8        8            9       1.0       3    0  27.0      0      2  1.251606
# 9        9           10       1.0       2    0  14.0      1      0  1.489814
# ..     ...          ...       ...     ...  ...   ...    ...    ...       ...
# 875    875          876       1.0       3    0  15.0      0      0  1.133715
# 879    879          880       1.0       1    0  56.0      0      1  1.692436
# 880    880          881       1.0       2    0  25.0      0      1  1.457646
# 887    887          888       1.0       1    0  19.0      0      0  1.489299
# 889    889          890       1.0       1    1  26.0      0      0  1.489299
#
#      Embarked
# 1           0
# ...

# %%
a.Age.value_counts()
# Out:
# Age
# 29.881138    52
# 24.000000    15
# 35.000000    11
# 27.000000    11
# 36.000000    11
#              ..
# 55.000000     1
# 32.500000     1
# 12.000000     1
# 0.920000      1
# 47.000000     1
# Name: count, Length: 66, dtype: int64

# %%
sns.displot(data=train, x='Survived', hue='Pclass', palette='coolwarm', kde=False)
plt.show()

# %%
sns.displot(data=train, x='Survived', hue='Sex', palette='coolwarm', kde=False)
plt.show()

# %%
sns.reset_orig()

# %%
sns.displot(data=train, x='Age', hue='Survived', palette='coolwarm', kde=False)
plt.show()

# %%
sns.histplot(train['Fare'], kde=True)
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.reset_defaults()
sns.reset_orig()
sns.histplot(data=train, x='Age', hue='Survived', palette='coolwarm', kde=False)
plt.show()

# %%
sns.histplot(train['Age'], kde=True)
plt.show()

# %%
class_fare = train.pivot_table(index ='Pclass',values ='Fare')
class_fare.plot(kind='bar')
plt.xlabel('Pclass')
plt.ylabel('Avg.Fare')
plt.xticks(rotation=0)
plt.show()

# %%
class_fare = train.pivot_table(index ='Pclass',values ='Fare',aggfunc=np.sum)
class_fare.plot(kind='bar')
plt.xlabel('Pclass')
plt.ylabel('Total Fare')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Data pre processing

# %%
train_len=len(train)
df=pd.concat([train,test],axis=0)
df =df.reset_index()

# %%
df
# Out:
#       index  PassengerId  Survived  Pclass  \
# 0         0            1       0.0       3
# 1         1            2       1.0       1
# 2         2            3       1.0       3
# 3         3            4       1.0       1
# 4         4            5       0.0       3
# ...     ...          ...       ...     ...
# 1304    413         1305       NaN       3
# 1305    414         1306       NaN       1
# 1306    415         1307       NaN       3
# 1307    416         1308       NaN       3
# 1308    417         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0      0            1       0.0       3
# 1      1            2       1.0       1
# 2      2            3       1.0       3
# 3      3            4       1.0       1
# 4      4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df.tail()
# Out:
#       index  PassengerId  Survived  Pclass                          Name  \
# 1304    413         1305       NaN       3            Spector, Mr. Woolf
# 1305    414         1306       NaN       1  Oliva y Ocana, Dona. Fermina
# 1306    415         1307       NaN       3  Saether, Mr. Simon Sivertsen
# 1307    416         1308       NaN       3           Ware, Mr. Frederick
# 1308    417         1309       NaN       3      Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 1304    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307    male   NaN      0      0              359309    8.0500   NaN        S
# 1308    male   NaN      1      1                2668   22.3583   NaN        C

# %%
df.isnull().sum()
# Out:
# index             0
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
df=df.drop(columns=['Cabin'],axis=1)

# %%
df
# Out:
#       index  PassengerId  Survived  Pclass  \
# 0         0            1       0.0       3
# 1         1            2       1.0       1
# 2         2            3       1.0       3
# 3         3            4       1.0       1
# 4         4            5       0.0       3
# ...     ...          ...       ...     ...
# 1304    413         1305       NaN       3
# 1305    414         1306       NaN       1
# 1306    415         1307       NaN       3
# 1307    416         1308       NaN       3
# 1308    417         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df['Age'].mean()
# Out:
# 29.881137667304014

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
df['Fare']=df['Fare'].fillna(df['Fare'].mean())

# %%
df['Embarked'].mode()[0]
# Out:
# 'S'

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
sns.histplot(train['Fare'], kde=True)
plt.show()

# %%
df['Fare']=np.log(df['Fare']+1)
df
# Out:
#       index  PassengerId  Survived  Pclass  \
# 0         0            1       0.0       3
# 1         1            2       1.0       1
# 2         2            3       1.0       3
# 3         3            4       1.0       1
# 4         4            5       0.0       3
# ...     ...          ...       ...     ...
# 1304    413         1305       NaN       3
# 1305    414         1306       NaN       1
# 1306    415         1307       NaN       3
# 1307    416         1308       NaN       3
# 1308    417         1309       NaN       3
#
#                                                    Name     Sex        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# ...

# %%
sns.histplot(train['Fare'], kde=True)
plt.show()

# %%
sns.distplot(df['Fare'])
plt.figure(figsize=(10, 6))  
sns.distplot(df['Fare'], bins=30, kde=True, color='blue')  


plt.title('Distribution of Fare Prices on the Titanic')
plt.xlabel('Fare')
plt.ylabel('Density')
plt.show()

# %%
df['Fare'] = np.log(df['Fare']+1)

# %%
plt.figure(figsize=(10, 6))  
sns.distplot(df['Fare'], bins=30, kde=True, color='blue')  


plt.title('Distribution of Fare Prices on the Titanic')
plt.xlabel('Fare')
plt.ylabel('Density')
plt.show()

# %%
a=train[train['Survived']==1]
a
# Out:
#      index  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  \
# 1        1            2       1.0       1    0  38.0      1      0  1.664038
# 2        2            3       1.0       3    0  26.0      0      0  1.159662
# 3        3            4       1.0       1    0  35.0      1      0  1.607603
# 8        8            9       1.0       3    0  27.0      0      2  1.251606
# 9        9           10       1.0       2    0  14.0      1      0  1.489814
# ..     ...          ...       ...     ...  ...   ...    ...    ...       ...
# 875    875          876       1.0       3    0  15.0      0      0  1.133715
# 879    879          880       1.0       1    0  56.0      0      1  1.692436
# 880    880          881       1.0       2    0  25.0      0      1  1.457646
# 887    887          888       1.0       1    0  19.0      0      0  1.489299
# 889    889          890       1.0       1    1  26.0      0      0  1.489299
#
#      Embarked
# 1           0
# ...

# %%
a['Survived'] = a['Survived'].round().astype(int)
a
# Out:
#      index  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  \
# 1        1            2         1       1    0  38.0      1      0  1.664038
# 2        2            3         1       3    0  26.0      0      0  1.159662
# 3        3            4         1       1    0  35.0      1      0  1.607603
# 8        8            9         1       3    0  27.0      0      2  1.251606
# 9        9           10         1       2    0  14.0      1      0  1.489814
# ..     ...          ...       ...     ...  ...   ...    ...    ...       ...
# 875    875          876         1       3    0  15.0      0      0  1.133715
# 879    879          880         1       1    0  56.0      0      1  1.692436
# 880    880          881         1       2    0  25.0      0      1  1.457646
# 887    887          888         1       1    0  19.0      0      0  1.489299
# 889    889          890         1       1    1  26.0      0      0  1.489299
#
#      Embarked
# 1           0
# ...

# %%
b=a[a["Pclass"]==1]
b
# Out:
#      index  PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch  \
# 1        1            2       1.0       1    0  38.000000      1      0
# 3        3            4       1.0       1    0  35.000000      1      0
# 11      11           12       1.0       1    0  58.000000      0      0
# 23      23           24       1.0       1    1  28.000000      0      0
# 31      31           32       1.0       1    0  29.881138      1      0
# ..     ...          ...       ...     ...  ...        ...    ...    ...
# 862    862          863       1.0       1    0  48.000000      0      0
# 871    871          872       1.0       1    0  47.000000      1      1
# 879    879          880       1.0       1    0  56.000000      0      1
# 887    887          888       1.0       1    0  19.000000      0      0
# 889    889          890       1.0       1    1  26.000000      0      0
#
#          Fare  Embarked
# 1    1.664038         0
# 3    1.607603         2
# 11   1.462330         2
# ...

# %%
b['Pclass'] = b['Pclass'].round().astype(int)
b
# Out:
#      index  PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch  \
# 1        1            2       1.0       1    0  38.000000      1      0
# 3        3            4       1.0       1    0  35.000000      1      0
# 11      11           12       1.0       1    0  58.000000      0      0
# 23      23           24       1.0       1    1  28.000000      0      0
# 31      31           32       1.0       1    0  29.881138      1      0
# ..     ...          ...       ...     ...  ...        ...    ...    ...
# 862    862          863       1.0       1    0  48.000000      0      0
# 871    871          872       1.0       1    0  47.000000      1      1
# 879    879          880       1.0       1    0  56.000000      0      1
# 887    887          888       1.0       1    0  19.000000      0      0
# 889    889          890       1.0       1    1  26.000000      0      0
#
#          Fare  Embarked
# 1    1.664038         0
# 3    1.607603         2
# 11   1.462330         2
# ...

# %%
b['Age'] = b['Age'].round().astype(int)
b
# Out:
#      index  PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch      Fare  \
# 1        1            2       1.0       1    0   38      1      0  1.664038
# 3        3            4       1.0       1    0   35      1      0  1.607603
# 11      11           12       1.0       1    0   58      0      0  1.462330
# 23      23           24       1.0       1    1   28      0      0  1.525472
# 31      31           32       1.0       1    0   30      1      0  1.790754
# ..     ...          ...       ...     ...  ...  ...    ...    ...       ...
# 862    862          863       1.0       1    0   48      0      0  1.457035
# 871    871          872       1.0       1    0   47      1      1  1.605569
# 879    879          880       1.0       1    0   56      0      1  1.692436
# 887    887          888       1.0       1    0   19      0      0  1.489299
# 889    889          890       1.0       1    1   26      0      0  1.489299
#
#      Embarked
# 1           0
# 3           2
# ...

# %%
b.Age.value_counts()
# Out:
# Age
# 30    19
# 35     9
# 36     7
# 24     5
# 48     5
# 38     4
# 39     4
# 49     4
# 22     4
# 27     3
# 52     3
# 33     3
# 42     3
# 16     3
# 18     3
# 17     3
# 58     3
# 23     3
# 31     3
# 40     3
# 19     3
# 26     2
# 45     2
# 56     2
# 28     2
# 54     2
# 51     2
# 44     2
# 50     2
# 25     2
# 60     2
# 32     2
# 21     2
# 29     1
# 15     1
# 62     1
# 11     1
# 80     1
# 43     1
# 41     1
# 53     1
# 34     1
# 4      1
# 14     1
# 1      1
# 63     1
# 37     1
# 47     1
# Name: count, dtype: int64

# %%
a=train[train['Survived']==1]
a

# %%
non_numeric_cols = df.select_dtypes(exclude=['number']).columns
print("Non-numeric columns:", non_numeric_cols)
df_numeric = df.drop(columns=non_numeric_cols)
corr = df_numeric.corr()
plt.figure(figsize=(15, 9))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# Non-numeric columns: Index(['Name', 'Sex', 'Ticket', 'Embarked'], dtype='object')

# %% [markdown]
# # correlation Matrix

# %%
df.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0      0            1       0.0       3
# 1      1            2       1.0       1
# 2      2            3       1.0       3
# 3      3            4       1.0       1
# 4      4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket      Fare Embarked
# 0      0         A/5 21171  1.134691        S
# 1      0          PC 17599  1.664038        C
# 2      0  STON/O2. 3101282  1.159662        S
# 3      0            113803  1.607603        S
# ...

# %%
df.head()
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0      0            1       0.0       3
# 1      1            2       1.0       1
# 2      2            3       1.0       3
# 3      3            4       1.0       1
# 4      4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket      Fare Embarked
# 0      0         A/5 21171  1.134691        S
# 1      0          PC 17599  1.664038        C
# 2      0  STON/O2. 3101282  1.159662        S
# 3      0            113803  1.607603        S
# ...

# %%
df = df.drop(columns=['Name', 'Ticket'], axis=1)
df.head()
# Out:
#    index  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Fare  \
# 0      0            1       0.0       3    male  22.0      1      0  1.134691
# 1      1            2       1.0       1  female  38.0      1      0  1.664038
# 2      2            3       1.0       3  female  26.0      0      0  1.159662
# 3      3            4       1.0       1  female  35.0      1      0  1.607603
# 4      4            5       0.0       3    male  35.0      0      0  1.164014
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Sex', 'Embarked']
le = LabelEncoder()

for col in cols:
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    index  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  \
# 0      0            1       0.0       3    1  22.0      1      0  1.134691
# 1      1            2       1.0       1    0  38.0      1      0  1.664038
# 2      2            3       1.0       3    0  26.0      0      0  1.159662
# 3      3            4       1.0       1    0  35.0      1      0  1.607603
# 4      4            5       0.0       3    1  35.0      0      0  1.164014
#
#    Embarked
# 0         2
# 1         0
# 2         2
# 3         2
# 4         2

# %% [markdown]
# # label coding

# %%
train_len = int(0.8 * len(df))  
train = df.iloc[:train_len, :]
test = df.iloc[train_len:, :]
train.head()
# Out:
#    index  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  \
# 0      0            1       0.0       3    1  22.0      1      0  1.134691
# 1      1            2       1.0       1    0  38.0      1      0  1.664038
# 2      2            3       1.0       3    0  26.0      0      0  1.159662
# 3      3            4       1.0       1    0  35.0      1      0  1.607603
# 4      4            5       0.0       3    1  35.0      0      0  1.164014
#
#    Embarked
# 0         2
# 1         0
# 2         2
# 3         2
# 4         2

# %% [markdown]
# # train-test [split]

# %%
test.head()
# Out:
#       index  PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch  \
# 1047    156         1048       NaN       1    0  29.000000      0      0
# 1048    157         1049       NaN       3    0  23.000000      0      0
# 1049    158         1050       NaN       1    1  42.000000      0      0
# 1050    159         1051       NaN       3    0  26.000000      0      2
# 1051    160         1052       NaN       3    0  29.881138      0      0
#
#           Fare  Embarked
# 1047  1.857263         2
# 1048  1.157162         2
# 1049  1.462330         2
# 1050  1.306422         2
# 1051  1.152830         1

# %%
a= train.drop(columns=['PassengerId', 'Survived'], axis=1)
b = train['Survived']

# %%
a.head()
# Out:
#    index  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 0      0       3    1  22.0      1      0  1.134691         2
# 1      1       1    0  38.0      1      0  1.664038         0
# 2      2       3    0  26.0      0      0  1.159662         2
# 3      3       1    0  35.0      1      0  1.607603         2
# 4      4       3    1  35.0      0      0  1.164014         2

# %%
b.head()
# Out:
# 0    0.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    0.0
# Name: Survived, dtype: float64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression


df = pd.read_csv('Titanic-Dataset.csv')


df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})  
df['Embarked'] = df['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})  


df['Age'].fillna(df['Age'].median(), inplace=True)
df['Fare'].fillna(df['Fare'].median(), inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)


df['Survived'].dropna(inplace=True)  


X = df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]
y = df['Survived']


def classify(model):
  
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

   
    model.fit(X_train, y_train)

   
    accuracy = model.score(X_test, y_test)
    print(f'Accuracy: {accuracy}')

   
    cv_scores = cross_val_score(model, X_train, y_train, cv=5)  
    cv_score = cv_scores.mean()  
    print(f'CV Score: {cv_score}')


model = LogisticRegression(max_iter=1000)


classify(model)
# Out:
# Accuracy: 0.8071748878923767
# CV Score: 0.7978453596678262

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model)
# Out:
# Accuracy: 0.8071748878923767
# CV Score: 0.7978453596678262

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model)
# Out:
# Accuracy: 0.726457399103139
# CV Score: 0.7530804623499046

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
classify(model)
# Out:
# Accuracy: 0.7802690582959642
# CV Score: 0.7844798563573112

# %%
test.head()
# Out:
#       index  PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch  \
# 1047    156         1048       NaN       1    0  29.000000      0      0
# 1048    157         1049       NaN       3    0  23.000000      0      0
# 1049    158         1050       NaN       1    1  42.000000      0      0
# 1050    159         1051       NaN       3    0  26.000000      0      2
# 1051    160         1052       NaN       3    0  29.881138      0      0
#
#           Fare  Embarked
# 1047  1.857263         2
# 1048  1.157162         2
# 1049  1.462330         2
# 1050  1.306422         2
# 1051  1.152830         1

# %%
X_test = test.drop(columns=['PassengerId', 'Survived'], axis=1)

# %%
X_test.head()
# Out:
#       index  Pclass  Sex        Age  SibSp  Parch      Fare  Embarked
# 1047    156       1    0  29.000000      0      0  1.857263         2
# 1048    157       3    0  23.000000      0      0  1.157162         2
# 1049    158       1    1  42.000000      0      0  1.462330         2
# 1050    159       3    0  26.000000      0      2  1.306422         2
# 1051    160       3    0  29.881138      0      0  1.152830         1

# %%
sub = pd.read_csv('gender_submission.csv')
sub.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %%
sub.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
Survival_counts = df['Survived'].value_counts()


plt.figure(figsize=(8, 8))
plt.pie(Survival_counts, labels=Survival_counts.index, autopct='%1.2f%%',)
plt.title('Survival count')
plt.show()

# %%
Survival_counts = df["Survived"].value_counts()

plt.figure(figsize=(7, 7))
plt.pie(Survival_counts, labels=Survival_counts.index, autopct=lambda p: f'{int(p*sum(Survival_counts)/100)}', 
        startangle=140, colors=[ 'purple', 'pink'])
plt.title("Survival_counts")
plt.show()

# %%
Gender = df["Sex"].value_counts()

plt.figure(figsize=(7, 7))
plt.pie(Gender, labels=Gender.index, autopct=lambda p: f'{int(p*sum(Gender)/100)}', 
        startangle=140, colors=['violet', 'pink'])
plt.title("Gender")
plt.show()

# %%
df.Sex.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Sex, Length: 891, dtype: int64>

# %%
Class = df["Pclass"].value_counts()

plt.figure(figsize=(7, 7))
plt.pie(Class, labels=Class.index, autopct=lambda p: f'{int(p*sum(Class)/100)}', 
        startangle=140, colors=['brown', 'pink','green'])
plt.title("Class")
plt.show()

# %%
df.Pclass.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64>

# %%
a=184
b=216
c=491
print(a+b+c)
# Out:
# 891

# %%
Charges=df.loc[(df['PassengerId'] >= 1) & (df['PassengerId'] <= 20)]
Charges=Charges.reset_index()
Charges
# Out:
#     index  PassengerId  Survived  Pclass  \
# 0       0            1         0       3
# 1       1            2         1       1
# 2       2            3         1       3
# 3       3            4         1       1
# 4       4            5         0       3
# 5       5            6         0       3
# 6       6            7         0       1
# 7       7            8         0       3
# 8       8            9         1       3
# 9       9           10         1       2
# 10     10           11         1       3
# 11     11           12         1       1
# 12     12           13         0       3
# 13     13           14         0       3
# 14     14           15         0       3
# 15     15           16         1       2
# 16     16           17         0       3
# 17     17           18         1       2
# 18     18           19         0       3
# 19     19           20         1       3
#
#                                                  Name  Sex   Age  SibSp  \
# ...

# %%
Charges = df["Fare"].value_counts()

plt.figure(figsize=(10, 10))
plt.pie(Charges, labels=Charges.index, autopct=lambda p: f'{int(p*sum(Charges)/100)}', 
        startangle=140, colors=['brown', 'pink','green'])
plt.title("Charges")
plt.show()

# %%
df.Fare.describe
# Out:
# <bound method NDFrame.describe of 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64>

# %%
df.Fare.max()
# Out:
# 512.3292

# %%
df.Fare.min()
# Out:
# 0.0

# %%
def assign_range(Fare):
    if Fare >= 500:
        return 'c1'
    elif Fare >= 400:
        return 'c2'
    elif Fare >= 300:
        return 'c3'
    elif Fare>= 200:
        return 'C4'
    elif Fare >=100:
        return 'C5'

    else:
        return 'c6'
df['FR'] = df['Fare'].apply(assign_range)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
Charges = df["FR"].value_counts()

plt.figure(figsize=(10, 10))
plt.pie(Charges, labels=Charges.index, autopct=lambda p: f'{int(p*sum(Charges)/100)}', 
        startangle=140, colors=['brown', 'pink','green','yellow','purple','orange'])
plt.title("Charges")
plt.show()
